# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pltb

# %%
df=pd.read_csv("/content/housing.csv")
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
print(df.shape)
# Out:
# (20640, 10)

# %%
print(df.head(10))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
# 5    -122.25     37.85                  52          919           213.0
# 6    -122.25     37.84                  52         2535           489.0
# 7    -122.25     37.84                  52         3104           687.0
# 8    -122.26     37.84                  42         2555           665.0
# 9    -122.25     37.84                  52         3549           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252            452600.0        NEAR BAY
# ...

# %%
print(df.tail(10))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20630    -121.32     39.29                  11         2640           505.0
# 20631    -121.40     39.33                  15         2655           493.0
# 20632    -121.45     39.26                  15         2319           416.0
# 20633    -121.53     39.19                  27         2080           412.0
# 20634    -121.56     39.27                  28         2332           395.0
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20630        1257         445         3.5673            112000.0
# ...

# %%
print(df.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
print(df['total_rooms'])
# Out:
# 0         880
# 1        7099
# 2        1467
# 3        1274
# 4        1627
#          ...
# 20635    1665
# 20636     697
# 20637    2254
# 20638    1860
# 20639    2785
# Name: total_rooms, Length: 20640, dtype: int64

# %%
x=df['total_rooms'].head(150).values.reshape(-1,1)
y=df['median_house_value'].head(150).values.reshape(-1,1)

# %%
pltb.scatter(x,y)
pltb.xlabel('total_rooms')
pltb.ylabel('median_house_value')
pltb.title('scatter plot of Total Rooms vs. Median House Values')
# Out:
# Text(0.5, 1.0, 'scatter plot of Total Rooms vs. Median House Values')
